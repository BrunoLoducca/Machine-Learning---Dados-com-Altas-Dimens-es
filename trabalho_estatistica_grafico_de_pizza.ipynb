# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunoLoducca/Machine-Learning---Dados-com-Altas-Dimens-es/blob/main/trabalho_estatistica_grafico_de_pizza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dados = "PIB-2020-CIDADES.csv"

pib_cidades = read.csv(dados)

head(pib_cidades)

library(dplyr)
# Out:
#   Ano  Código.da.Grande.Região Nome.da.Grande.Região
# 1 2020 1                       Norte
# 2 2020 1                       Norte
# 3 2020 1                       Norte
# 4 2020 1                       Norte
# 5 2020 1                       Norte
# 6 2020 1                       Norte
#   Código.da.Unidade.da.Federação Sigla.da.Unidade.da.Federação
# 1 11                             RO
# 2 11                             RO
# 3 11                             RO
# 4 11                             RO
# 5 11                             RO
# 6 11                             RO
#   Nome.da.Unidade.da.Federação Código.do.Município Nome.do.Município
# 1 Rondônia                     1100015             Alta Floresta D'Oeste
# 2 Rondônia                     1100023             Ariquemes
# 3 Rondônia                     1100031             Cabixi
# 4 Rondônia                     1100049             Cacoal
# 5 Rondônia                     1100056             Cerejeiras
# ...

# %%
valores_adicionados = select(pib_cidades, Nome.da.Grande.Região, Sigla.da.Unidade.da.Federação, Nome.da.Unidade.da.Federação, Nome.do.Município,
Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.,
Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000., Valor.adicionado.bruto.dos.Serviços..a.preços.correntes....exceto.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social..R..1.000.,
Valor.adicionado.bruto.da.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social...a.preços.correntes..R..1.000.,
Valor.adicionado.bruto.total...a.preços.correntes..R..1.000.)

# %%
head(valores_adicionados)
# Out:
#   Nome.da.Grande.Região Sigla.da.Unidade.da.Federação
# 1 Norte                 RO
# 2 Norte                 RO
# 3 Norte                 RO
# 4 Norte                 RO
# 5 Norte                 RO
# 6 Norte                 RO
#   Nome.da.Unidade.da.Federação Nome.do.Município
# 1 Rondônia                     Alta Floresta D'Oeste
# 2 Rondônia                     Ariquemes
# 3 Rondônia                     Cabixi
# 4 Rondônia                     Cacoal
# 5 Rondônia                     Cerejeiras
# 6 Rondônia                     Colorado do Oeste
#   Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.
# 1 203394.42
# 2 199722.71
# 3  81177.10
# 4 236214.95
# 5  94757.64
# 6  88922.64
#   Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.
# 1  20716.40
# 2 404751.76
# 3   5438.03
# 4 275536.82
# 5  23582.33
# 6  24321.93
# ...

# %%
# Região Norte

valores_adicionados_Norte = filter(valores_adicionados, Nome.da.Grande.Região=="Norte")

head(valores_adicionados_Norte)
# Out:
#   Nome.da.Grande.Região Sigla.da.Unidade.da.Federação
# 1 Norte                 RO
# 2 Norte                 RO
# 3 Norte                 RO
# 4 Norte                 RO
# 5 Norte                 RO
# 6 Norte                 RO
#   Nome.da.Unidade.da.Federação Nome.do.Município
# 1 Rondônia                     Alta Floresta D'Oeste
# 2 Rondônia                     Ariquemes
# 3 Rondônia                     Cabixi
# 4 Rondônia                     Cacoal
# 5 Rondônia                     Cerejeiras
# 6 Rondônia                     Colorado do Oeste
#   Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.
# 1 203394.42
# 2 199722.71
# 3  81177.10
# 4 236214.95
# 5  94757.64
# 6  88922.64
#   Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.
# 1  20716.40
# 2 404751.76
# 3   5438.03
# 4 275536.82
# 5  23582.33
# 6  24321.93
# ...

# %%
#Região Norte

valores_agropecuaria_Norte = sum(valores_adicionados_Norte$Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.)
valores_agropecuaria_Norte

print("")

valores_industria_Norte = sum(valores_adicionados_Norte$Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.)
valores_industria_Norte

print("")

valores_servicos_Norte = sum(valores_adicionados_Norte$Valor.adicionado.bruto.dos.Serviços..a.preços.correntes....exceto.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social..R..1.000.)
valores_servicos_Norte

print("")

valores_administracao_Norte = sum(valores_adicionados_Norte$Valor.adicionado.bruto.da.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social...a.preços.correntes..R..1.000.)
valores_administracao_Norte

print("")

totais_norte = valores_agropecuaria_Norte + valores_industria_Norte + valores_servicos_Norte + valores_administracao_Norte
totais_norte
# Out:
# [1] 42094037
# [1] ""
# [1] 137740479
# [1] ""
# [1] 144262069
# [1] ""
# [1] 102057624
# [1] ""
# [1] 426154208
# [1] 42094037
# [1] ""
# [1] 137740479
# [1] ""
# [1] 144262069
# [1] ""
# [1] 102057624
# [1] ""
# [1] 426154208
# [1] 42094037
# [1] ""
# [1] 137740479
# [1] ""
# [1] 144262069
# [1] ""
# [1] 102057624
# [1] ""
# [1] 426154208

# %%
# Calculando a porcentagem da região norte:

proporcao_agro_norte = round((valores_agropecuaria_Norte/ totais_norte)*100)
proporcao_agro_norte

print("")

proporcao_industria_norte = round((valores_industria_Norte/ totais_norte)*100)
proporcao_industria_norte

print("")

proporcao_servicos_norte = round((valores_servicos_Norte/ totais_norte)*100)
proporcao_servicos_norte

print("")

proporcao_administracao_norte = round((valores_administracao_Norte/ totais_norte)*100)
proporcao_administracao_norte
# Out:
# [1] 10
# [1] ""
# [1] 32
# [1] ""
# [1] 34
# [1] ""
# [1] 24
# [1] 10
# [1] ""
# [1] 32
# [1] ""
# [1] 34
# [1] ""
# [1] 24
# [1] 10
# [1] ""
# [1] 32
# [1] ""
# [1] 34
# [1] ""
# [1] 24

# %%
# Nome da região Nordeste

valores_adicionados_Nordeste = filter(valores_adicionados, Nome.da.Grande.Região=="Nordeste")

head(valores_adicionados_Nordeste)

valores_agropecuaria_Nordeste = sum(valores_adicionados_Nordeste$Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.)
valores_agropecuaria_Nordeste

print("")

valores_industria_Nordeste = sum(valores_adicionados_Nordeste$Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.)
valores_industria_Nordeste

print("")

valores_servicos_Nordeste = sum(valores_adicionados_Nordeste$Valor.adicionado.bruto.dos.Serviços..a.preços.correntes....exceto.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social..R..1.000.)
valores_servicos_Nordeste

print("")

valores_administracao_Nordeste = sum(valores_adicionados_Nordeste$Valor.adicionado.bruto.da.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social...a.preços.correntes..R..1.000.)
valores_administracao_Nordeste

totais_nordeste = valores_agropecuaria_Nordeste + valores_industria_Nordeste + valores_servicos_Nordeste + valores_administracao_Nordeste
totais_nordeste
# Out:
#   Nome.da.Grande.Região Sigla.da.Unidade.da.Federação
# 1 Nordeste              MA
# 2 Nordeste              MA
# 3 Nordeste              MA
# 4 Nordeste              MA
# 5 Nordeste              MA
# 6 Nordeste              MA
#   Nome.da.Unidade.da.Federação Nome.do.Município
# 1 Maranhão                     Açailândia
# 2 Maranhão                     Afonso Cunha
# 3 Maranhão                     Água Doce do Maranhão
# 4 Maranhão                     Alcântara
# 5 Maranhão                     Aldeias Altas
# 6 Maranhão                     Altamira do Maranhão
#   Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.
# 1 365768.94
# 2  26213.34
# 3   5713.86
# 4  15106.95
# 5  48225.28
# 6  14763.05
#   Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.
# 1 704463.58
# 2   2317.95
# 3   3812.07
# 4   6998.76
# 5  16229.99
# 6   1637.67
# ...

# %%
# porcentagem do nordeste

proporcao_agro_nordeste = round((valores_agropecuaria_Nordeste/ totais_nordeste)*100)
proporcao_agro_nordeste

print("")

proporcao_industria_nordeste = round((valores_industria_Nordeste/ totais_nordeste)*100)
proporcao_industria_nordeste

print("")

proporcao_servicos_nordeste = round((valores_servicos_Nordeste/ totais_nordeste)*100)
proporcao_servicos_nordeste

print("")

proporcao_administracao_nordeste = round((valores_administracao_Nordeste/ totais_nordeste)*100)
proporcao_administracao_nordeste
# Out:
# [1] 9
# [1] ""
# [1] 19
# [1] ""
# [1] 46
# [1] ""
# [1] 26
# [1] 9
# [1] ""
# [1] 19
# [1] ""
# [1] 46
# [1] ""
# [1] 26
# [1] 9
# [1] ""
# [1] 19
# [1] ""
# [1] 46
# [1] ""
# [1] 26

# %%
# Região Sul

valores_adicionados_Sul = filter(valores_adicionados, Nome.da.Grande.Região=="Sul")

head(valores_adicionados_Sul)

valores_agropecuaria_Sul  = sum(valores_adicionados_Sul$Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.)
valores_agropecuaria_Sul

print("")

valores_industria_Sul  = sum(valores_adicionados_Sul$Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.)
valores_industria_Sul

print("")

valores_servicos_Sul  = sum(valores_adicionados_Sul$Valor.adicionado.bruto.dos.Serviços..a.preços.correntes....exceto.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social..R..1.000.)
valores_servicos_Sul

print("")

valores_administracao_Sul  = sum(valores_adicionados_Sul$Valor.adicionado.bruto.da.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social...a.preços.correntes..R..1.000.)
valores_administracao_Sul

print("")

totais_sul = valores_agropecuaria_Sul + valores_industria_Sul + valores_servicos_Sul + valores_administracao_Sul
totais_sul
# Out:
#   Nome.da.Grande.Região Sigla.da.Unidade.da.Federação
# 1 Sul                   PR
# 2 Sul                   PR
# 3 Sul                   PR
# 4 Sul                   PR
# 5 Sul                   PR
# 6 Sul                   PR
#   Nome.da.Unidade.da.Federação Nome.do.Município
# 1 Paraná                       Abatiá
# 2 Paraná                       Adrianópolis
# 3 Paraná                       Agudos do Sul
# 4 Paraná                       Almirante Tamandaré
# 5 Paraná                       Altamira do Paraná
# 6 Paraná                       Altônia
#   Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.
# 1 125850.39
# 2  22390.94
# 3  74788.82
# 4  39268.11
# 5  42770.69
# 6  95557.87
#   Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.
# 1  10809.49
# 2 151211.99
# 3  10361.05
# 4 386251.57
# 5   2788.68
# 6  26012.80
# ...

# %%
# porcentagem do sul

proporcao_agro_sul = round((valores_agropecuaria_Sul/ totais_sul)*100)
proporcao_agro_sul

print("")

proporcao_industria_sul = round((valores_industria_Sul/ totais_sul)*100)
proporcao_industria_sul

print("")

proporcao_servicos_sul = round((valores_servicos_Sul/ totais_sul)*100)
proporcao_servicos_sul

print("")

proporcao_administracao_sul = round((valores_administracao_Sul/ totais_sul)*100)
proporcao_administracao_sul
# Out:
# [1] 10
# [1] ""
# [1] 25
# [1] ""
# [1] 51
# [1] ""
# [1] 14
# [1] 10
# [1] ""
# [1] 25
# [1] ""
# [1] 51
# [1] ""
# [1] 14
# [1] 10
# [1] ""
# [1] 25
# [1] ""
# [1] 51
# [1] ""
# [1] 14

# %%
# Região Sudeste

valores_adicionados_Sudeste = filter(valores_adicionados, Nome.da.Grande.Região=="Sudeste")

head(valores_adicionados_Sudeste)

valores_agropecuaria_Sudeste = sum(valores_adicionados_Sudeste$Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.)
valores_agropecuaria_Sudeste

print("")

valores_industria_Sudeste = sum(valores_adicionados_Sudeste$Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.)
valores_industria_Sudeste

print("")

valores_servicos_Sudeste = sum(valores_adicionados_Sudeste$Valor.adicionado.bruto.dos.Serviços..a.preços.correntes....exceto.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social..R..1.000.)
valores_servicos_Sudeste

print("")

valores_administracao_Sudeste = sum(valores_adicionados_Sudeste$Valor.adicionado.bruto.da.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social...a.preços.correntes..R..1.000.)
valores_administracao_Sudeste

totais_sudeste = valores_agropecuaria_Sudeste + valores_industria_Sudeste + valores_servicos_Sudeste + valores_administracao_Sudeste
totais_sudeste
# Out:
#   Nome.da.Grande.Região Sigla.da.Unidade.da.Federação
# 1 Sudeste               MG
# 2 Sudeste               MG
# 3 Sudeste               MG
# 4 Sudeste               MG
# 5 Sudeste               MG
# 6 Sudeste               MG
#   Nome.da.Unidade.da.Federação Nome.do.Município
# 1 Minas Gerais                 Abadia dos Dourados
# 2 Minas Gerais                 Abaeté
# 3 Minas Gerais                 Abre Campo
# 4 Minas Gerais                 Acaiaca
# 5 Minas Gerais                 Açucena
# 6 Minas Gerais                 Água Boa
#   Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.
# 1 55678.20
# 2 98418.99
# 3 43747.39
# 4  3440.20
# 5 18445.54
# 6 43548.35
#   Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.
# 1  9667.09
# 2 77238.98
# 3 12331.25
# 4  6847.00
# 5 54659.42
# 6 11268.39
#   Valor.adicionado.bruto.dos.Serviços..a.preços.correntes....exceto.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social..R..1.000.
# ...

# %%
# porcentagem do sudeste

proporcao_agro_sudeste = round((valores_agropecuaria_Sudeste/ totais_sudeste)*100)
proporcao_agro_sudeste

print("")

proporcao_industria_sudeste = round((valores_industria_Sudeste/ totais_sudeste)*100)
proporcao_industria_sudeste

print("")

proporcao_servicos_sudeste = round((valores_servicos_Sudeste/ totais_sudeste)*100)
proporcao_servicos_sudeste

print("")

proporcao_administracao_sudeste = round((valores_administracao_Sudeste/ totais_sudeste)*100)
proporcao_administracao_sudeste
# Out:
# [1] 3
# [1] ""
# [1] 23
# [1] ""
# [1] 61
# [1] ""
# [1] 13
# [1] 3
# [1] ""
# [1] 23
# [1] ""
# [1] 61
# [1] ""
# [1] 13
# [1] 3
# [1] ""
# [1] 23
# [1] ""
# [1] 61
# [1] ""
# [1] 13

# %%
região = c("Norte", "Nordeste", "Sul", "Sudeste")

agropecuaria = c(proporcao_agro_norte, proporcao_agro_nordeste, proporcao_agro_sul, proporcao_agro_sudeste)

industria = c(proporcao_industria_norte, proporcao_industria_nordeste, proporcao_industria_sul, proporcao_industria_sudeste)

servicos = c(proporcao_servicos_norte, proporcao_servicos_nordeste, proporcao_servicos_sul, proporcao_servicos_sudeste)

administracao = c(proporcao_administracao_norte, proporcao_administracao_nordeste, proporcao_administracao_sul, proporcao_administracao_sudeste)

# Criando um data frame

dados = data.frame(região, agropecuaria, industria, servicos, administracao)

dados
# Out:
#   região   agropecuaria industria servicos administracao
# 1 Norte    10           32        34       24
# 2 Nordeste  9           19        46       26
# 3 Sul      10           25        51       14
# 4 Sudeste   3           23        61       13
#   região   agropecuaria industria servicos administracao
# 1 Norte    10           32        34       24
# 2 Nordeste  9           19        46       26
# 3 Sul      10           25        51       14
# 4 Sudeste   3           23        61       13
#   região   agropecuaria industria servicos administracao
# 1 Norte    10           32        34       24
# 2 Nordeste  9           19        46       26
# 3 Sul      10           25        51       14
# 4 Sudeste   3           23        61       13

# %%
dados_Norte = filter(dados, região=="Norte")
dados_Norte
# Out:
#   região agropecuaria industria servicos administracao
# 1 Norte  10           32        34       24
#   região agropecuaria industria servicos administracao
# 1 Norte  10           32        34       24
#   região agropecuaria industria servicos administracao
# 1 Norte  10           32        34       24

# %%
valores <- c(dados_Norte$agropecuaria, dados_Norte$industria, dados_Norte$servicos, dados_Norte$administracao)
valores
# Out:
# [1] 10 32 34 24
# [1] 10 32 34 24
# [1] 10 32 34 24

# %%
# Instale o pacote ggplot2 se ainda não o tiver instalado
# install.packages("ggplot2")

library(ggplot2)

# Crie os vetores de categoria e valor corretamente
categorias <- c("Agropecuaria", "Industria", "Servicos", "Administracao")
valores <- c(dados_Norte$agropecuaria, dados_Norte$industria, dados_Norte$servicos, dados_Norte$administracao)

# Crie o dataframe com os dados
dados_Norte <- data.frame(
  Categoria = categorias,
  Valor = valores
)



# Crie o gráfico de pizza
grafico <- ggplot(dados_Norte, aes(x = "", y = Valor, fill = Categoria)) +
  geom_bar(stat = "identity", width = 1) +
  coord_polar(theta = "y") +
  labs(fill = "Categoria") +
  theme_void() +
  geom_text(aes(label = paste0((Valor), "%")), position = position_stack(vjust = 0.5), color = "white", size = 5)

# Exiba o gráfico
print(grafico)
# Out:
# plot without title
# plot without title
# plot without title

# %%
dados
# Out:
#   região   agropecuaria industria servicos administracao
# 1 Norte    10           32        34       24
# 2 Nordeste  9           19        46       26
# 3 Sul      10           25        51       14
# 4 Sudeste   3           23        61       13
#   região   agropecuaria industria servicos administracao
# 1 Norte    10           32        34       24
# 2 Nordeste  9           19        46       26
# 3 Sul      10           25        51       14
# 4 Sudeste   3           23        61       13
#   região   agropecuaria industria servicos administracao
# 1 Norte    10           32        34       24
# 2 Nordeste  9           19        46       26
# 3 Sul      10           25        51       14
# 4 Sudeste   3           23        61       13

# %%
dados_Nordeste = filter(dados, região=="Nordeste")
dados_Nordeste
# Out:
#   região   agropecuaria industria servicos administracao
# 1 Nordeste 9            19        46       26
#   região   agropecuaria industria servicos administracao
# 1 Nordeste 9            19        46       26
#   região   agropecuaria industria servicos administracao
# 1 Nordeste 9            19        46       26

# %%
# Instale o pacote ggplot2 se ainda não o tiver instalado
# install.packages("ggplot2")

library(ggplot2)

# Crie os vetores de categoria e valor corretamente
categorias <- c("Agropecuaria", "Industria", "Servicos", "Administracao")
valores <- c(dados_Nordeste$agropecuaria, dados_Nordeste$industria, dados_Nordeste$servicos, dados_Nordeste$administracao)

# Crie o dataframe com os dados
dados_Nordeste <- data.frame(
  Categoria = categorias,
  Valor = valores
)

# Crie o gráfico de pizza
grafico <- ggplot(dados_Nordeste, aes(x = "", y = Valor, fill = Categoria)) +
  geom_bar(stat = "identity", width = 1) +
  coord_polar(theta = "y") +
  labs(fill = "Categoria") +
  theme_void() +
  geom_text(aes(label = paste0((Valor), "%")), position = position_stack(vjust = 0.5), color = "white", size = 5)

# Exiba o gráfico
print(grafico)
# Out:
# plot without title
# plot without title
# plot without title

# %%
dados_Sul = filter(dados, região=="Sul")
dados_Sul
# Out:
#   região agropecuaria industria servicos administracao
# 1 Sul    10           25        51       14
#   região agropecuaria industria servicos administracao
# 1 Sul    10           25        51       14
#   região agropecuaria industria servicos administracao
# 1 Sul    10           25        51       14

# %%
# Crie os vetores de categoria e valor corretamente
categorias <- c("Agropecuaria", "Industria", "Servicos", "Administracao")
valores <- c(dados_Sul$agropecuaria, dados_Sul$industria, dados_Sul$servicos, dados_Sul$administracao)

# Crie o dataframe com os dados
dados_Sul <- data.frame(
  Categoria = categorias,
  Valor = valores
)

# Crie o gráfico de pizza
grafico <- ggplot(dados_Sul, aes(x = "", y = Valor, fill = Categoria)) +
  geom_bar(stat = "identity", width = 1) +
  coord_polar(theta = "y") +
  labs(fill = "Categoria") +
  theme_void() +
  geom_text(aes(label = paste0((Valor), "%")), position = position_stack(vjust = 0.5), color = "white", size = 5)

# Exiba o gráfico
print(grafico)
# Out:
# plot without title
# plot without title
# plot without title

# %%
dados_Sudeste = filter(dados, região=="Sudeste")
dados_Sudeste
# Out:
#   região  agropecuaria industria servicos administracao
# 1 Sudeste 3            23        61       13
#   região  agropecuaria industria servicos administracao
# 1 Sudeste 3            23        61       13
#   região  agropecuaria industria servicos administracao
# 1 Sudeste 3            23        61       13

# %%
# Crie os vetores de categoria e valor corretamente
categorias <- c("Agropecuaria", "Industria", "Servicos", "Administracao")
valores <- c(dados_Sudeste$agropecuaria, dados_Sudeste$industria, dados_Sudeste$servicos, dados_Sudeste$administracao)

# Crie o dataframe com os dados
dados_Sudeste <- data.frame(
  Categoria = categorias,
  Valor = valores
)

# Crie o gráfico de pizza
grafico <- ggplot(dados_Sudeste, aes(x = "", y = Valor, fill = Categoria)) +
  geom_bar(stat = "identity", width = 1) +
  coord_polar(theta = "y") +
  labs(fill = "Categoria") +
  theme_void() +
  #geom_text(aes(label = Valor), position = position_stack(vjust = 0.5), color = "white", size = 6)
  geom_text(aes(label = paste0((Valor), "%")), position = position_stack(vjust = 0.5), color = "white", size = 5)




# Exiba o gráfico
print(grafico)
# Out:
# plot without title
# plot without title
# plot without title

# %%
dados_CO = filter(dados, região=="Centro Oeste")
dados_CO
# Out:
#      região agropecuaria industria servicos administracao
#      região agropecuaria industria servicos administracao
#      região agropecuaria industria servicos administracao

# %%
dados = "PIB-2020-CIDADES (1).csv"

pib_cidades = read.csv(dados)

head(pib_cidades)

library(dplyr)
# Out:
#   Ano  Código.da.Grande.Região Nome.da.Grande.Região
# 1 2020 1                       Norte
# 2 2020 1                       Norte
# 3 2020 1                       Norte
# 4 2020 1                       Norte
# 5 2020 1                       Norte
# 6 2020 1                       Norte
#   Código.da.Unidade.da.Federação Sigla.da.Unidade.da.Federação
# 1 11                             RO
# 2 11                             RO
# 3 11                             RO
# 4 11                             RO
# 5 11                             RO
# 6 11                             RO
#   Nome.da.Unidade.da.Federação Código.do.Município Nome.do.Município
# 1 Rondônia                     1100015             Alta Floresta D'Oeste
# 2 Rondônia                     1100023             Ariquemes
# 3 Rondônia                     1100031             Cabixi
# 4 Rondônia                     1100049             Cacoal
# 5 Rondônia                     1100056             Cerejeiras
# ...

# %%
fonte = ("PIB-2020-CIDADES_CO.csv")

dados_CO = read.csv(fonte)
head(dados_CO)
# Out:
#   Ano  Código.da.Grande.Região Nome.da.Grande.Região
# 1 2020 4                       Centro-oeste
# 2 2020 5                       Centro-oeste
# 3 2020 5                       Centro-oeste
# 4 2020 5                       Centro-oeste
# 5 2020 5                       Centro-oeste
# 6 2020 5                       Centro-oeste
#   Código.da.Unidade.da.Federação Sigla.da.Unidade.da.Federação
# 1 43                             RS
# 2 50                             MS
# 3 50                             MS
# 4 50                             MS
# 5 50                             MS
# 6 50                             MS
#   Nome.da.Unidade.da.Federação Código.do.Município Nome.do.Município
# 1 Rio Grande do Sul            4323804             Xangri-lá
# 2 Mato Grosso do Sul           5000203             Água Clara
# 3 Mato Grosso do Sul           5000252             Alcinópolis
# 4 Mato Grosso do Sul           5000609             Amambai
# ...

# %%
valores_adicionados_CO = select(dados_CO, Nome.da.Grande.Região, Sigla.da.Unidade.da.Federação, Nome.da.Unidade.da.Federação, Nome.do.Município,
Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.,
Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000., Valor.adicionado.bruto.dos.Serviços..a.preços.correntes....exceto.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social..R..1.000.,
Valor.adicionado.bruto.da.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social...a.preços.correntes..R..1.000.,
Valor.adicionado.bruto.total...a.preços.correntes..R..1.000.)

# %%
head(valores_adicionados_CO)
# Out:
#   Nome.da.Grande.Região Sigla.da.Unidade.da.Federação
# 1 Centro-oeste          RS
# 2 Centro-oeste          MS
# 3 Centro-oeste          MS
# 4 Centro-oeste          MS
# 5 Centro-oeste          MS
# 6 Centro-oeste          MS
#   Nome.da.Unidade.da.Federação Nome.do.Município
# 1 Rio Grande do Sul            Xangri-lá
# 2 Mato Grosso do Sul           Água Clara
# 3 Mato Grosso do Sul           Alcinópolis
# 4 Mato Grosso do Sul           Amambai
# 5 Mato Grosso do Sul           Anastácio
# 6 Mato Grosso do Sul           Anaurilândia
#   Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.
# 1   2090.22
# 2 425098.17
# 3 133644.55
# 4 318417.72
# 5 106436.93
# 6 143014.87
#   Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.
# 1  90271.88
# 2 281580.97
# 3   8519.59
# 4  90703.90
# 5  89523.99
# 6  19828.82
# ...

# %%
valores_adicionados_Centro_Oeste = filter(valores_adicionados_CO, Nome.da.Grande.Região=="Centro-oeste")

head(valores_adicionados_Centro_Oeste)
# Out:
#   Nome.da.Grande.Região Sigla.da.Unidade.da.Federação
# 1 Centro-oeste          RS
# 2 Centro-oeste          MS
# 3 Centro-oeste          MS
# 4 Centro-oeste          MS
# 5 Centro-oeste          MS
# 6 Centro-oeste          MS
#   Nome.da.Unidade.da.Federação Nome.do.Município
# 1 Rio Grande do Sul            Xangri-lá
# 2 Mato Grosso do Sul           Água Clara
# 3 Mato Grosso do Sul           Alcinópolis
# 4 Mato Grosso do Sul           Amambai
# 5 Mato Grosso do Sul           Anastácio
# 6 Mato Grosso do Sul           Anaurilândia
#   Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.
# 1   2090.22
# 2 425098.17
# 3 133644.55
# 4 318417.72
# 5 106436.93
# 6 143014.87
#   Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.
# 1  90271.88
# 2 281580.97
# 3   8519.59
# 4  90703.90
# 5  89523.99
# 6  19828.82
# ...

# %%
# Região Centro-oeste

valores_agropecuaria_Centro_Oeste = sum(valores_adicionados_Centro_Oeste$Valor.adicionado.bruto.da.Agropecuária...a.preços.correntes..R..1.000.)
valores_agropecuaria_Centro_Oeste

print("")

valores_industria_Centro_Oeste = sum(valores_adicionados_Centro_Oeste$Valor.adicionado.bruto.da.Indústria..a.preços.correntes..R..1.000.)
valores_industria_Centro_Oeste

print("")

valores_servicos_Centro_Oeste = sum(valores_adicionados_Centro_Oeste$Valor.adicionado.bruto.dos.Serviços..a.preços.correntes....exceto.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social..R..1.000.)
valores_servicos_Centro_Oeste

print("")

valores_administracao_Centro_Oeste = sum(valores_adicionados_Centro_Oeste$Valor.adicionado.bruto.da.Administração..defesa..educação.e.saúde.públicas.e.seguridade.social...a.preços.correntes..R..1.000.)
valores_administracao_Centro_Oeste

print("")

totais_coeste = valores_agropecuaria_Centro_Oeste + valores_industria_Centro_Oeste + valores_servicos_Centro_Oeste + valores_administracao_Centro_Oeste
totais_coeste
# Out:
# [1] 101073981
# [1] ""
# [1] 98192609
# [1] ""
# [1] 192847251
# [1] ""
# [1] 77799945
# [1] ""
# [1] 469913785
# [1] 101073981
# [1] ""
# [1] 98192609
# [1] ""
# [1] 192847251
# [1] ""
# [1] 77799945
# [1] ""
# [1] 469913785
# [1] 101073981
# [1] ""
# [1] 98192609
# [1] ""
# [1] 192847251
# [1] ""
# [1] 77799945
# [1] ""
# [1] 469913785

# %%
# porcentagem do sudeste

proporcao_agro_coeste = round((valores_agropecuaria_Centro_Oeste/ totais_coeste)*100)
proporcao_agro_coeste

print("")

proporcao_industria_coeste = round((valores_industria_Centro_Oeste/ totais_coeste)*100)
proporcao_industria_coeste

print("")

proporcao_servicos_coeste = round((valores_servicos_Centro_Oeste/ totais_coeste)*100)
proporcao_servicos_coeste

print("")

proporcao_administracao_coeste = round((valores_administracao_Centro_Oeste/ totais_coeste)*100)
proporcao_administracao_coeste
# Out:
# [1] 22
# [1] ""
# [1] 21
# [1] ""
# [1] 41
# [1] ""
# [1] 17
# [1] 22
# [1] ""
# [1] 21
# [1] ""
# [1] 41
# [1] ""
# [1] 17
# [1] 22
# [1] ""
# [1] 21
# [1] ""
# [1] 41
# [1] ""
# [1] 17

# %%
região = c("Centro-oeste")

agropecuaria = c(proporcao_agro_coeste)

industria = c(proporcao_industria_coeste)

servicos = c(proporcao_servicos_coeste)

administracao = c(proporcao_administracao_coeste)

# Criando um data frame

dados_CO = data.frame(região, agropecuaria, industria, servicos, administracao)

dados_CO
# Out:
#   região       agropecuaria industria servicos administracao
# 1 Centro-oeste 22           21        41       17
#   região       agropecuaria industria servicos administracao
# 1 Centro-oeste 22           21        41       17
#   região       agropecuaria industria servicos administracao
# 1 Centro-oeste 22           21        41       17

# %%
# Crie os vetores de categoria e valor corretamente
categorias <- c("Agropecuaria", "Industria", "Servicos", "Administracao")
valores <- c(dados_CO$agropecuaria, dados_CO$industria, dados_CO$servicos, dados_CO$administracao)

# Crie o dataframe com os dados
dados_Centro_Oeste <- data.frame(
  Categoria = categorias,
  Valor = valores
)

# Crie o gráfico de pizza
grafico <- ggplot(dados_Centro_Oeste, aes(x = "", y = Valor, fill = Categoria)) +
  geom_bar(stat = "identity", width = 1) +
  coord_polar(theta = "y") +
  labs(fill = "Categoria") +
  theme_void() +
  geom_text(aes(label = paste0((Valor), "%")), position = position_stack(vjust = 0.5), color = "white", size = 5)

# Exiba o gráfico
print(grafico)
# Out:
# plot without title
# plot without title
# plot without title

# %%
# dados para o facegrid

regioes = c("Norte", "Nordeste", "Sul", "Sudeste", "Centro Oeste")
valores = c(proporcao_agro_norte, proporcao_agro_nordeste, proporcao_agro_sul,
            proporcao_agro_sudeste, proporcao_agro_coeste)

# %%
# Criar o gráfico de barras
barplot(valores, names.arg = regioes, xlab = "Regiões", ylab = "Proporção do PIB", main="Contribuição da agropecuária dos PIB's por região", col="blue")
# Out:
# Plot with title “Contribuição da agropecuária dos PIB's por região”
# Plot with title “Contribuição da agropecuária dos PIB's por região”
# Plot with title “Contribuição da agropecuária dos PIB's por região”

# %%
regioes = c("Norte", "Nordeste", "Sul", "Sudeste", "Centro Oeste")
valores = c(proporcao_industria_norte, proporcao_industria_nordeste, proporcao_industria_sul,
            proporcao_industria_sudeste, proporcao_industria_coeste)

barplot(valores, names.arg = regioes, xlab = "Regiões", ylab = "Proporção do PIB", main="Contribuição da agropecuária dos PIB's por região", col="blue")
# Out:
# Plot with title “Contribuição da agropecuária dos PIB's por região”
# Plot with title “Contribuição da agropecuária dos PIB's por região”
# Plot with title “Contribuição da agropecuária dos PIB's por região”

# %%
regioes = c("Norte", "Nordeste", "Sul", "Sudeste", "Centro Oeste")
valores = c(proporcao_servicos_norte, proporcao_servicos_nordeste, proporcao_servicos_sul,
            proporcao_servicos_sudeste, proporcao_servicos_coeste)

barplot(valores, names.arg = regioes, xlab = "Regiões", ylab = "Proporção do PIB", main="Contribuição dos serviços dos PIB's por região", col="blue")
# Out:
# Plot with title “Contribuição dos serviços dos PIB's por região”
# Plot with title “Contribuição dos serviços dos PIB's por região”
# Plot with title “Contribuição dos serviços dos PIB's por região”

# %%
regioes = c("Norte", "Nordeste", "Sul", "Sudeste", "Centro Oeste")
valores = c(proporcao_administracao_norte, proporcao_administracao_nordeste, proporcao_administracao_sul,
            proporcao_administracao_sudeste, proporcao_administracao_coeste)

barplot(valores, names.arg = regioes, xlab = "Regiões", ylab = "Proporção do PIB", main="Contribuição da administração dos PIB's por região", col="blue")
# Out:
# Plot with title “Contribuição da administração dos PIB's por região”
# Plot with title “Contribuição da administração dos PIB's por região”
# Plot with title “Contribuição da administração dos PIB's por região”

# %%
total_brasil = valores_agropecuaria_Centro_Oeste + valores_industria_Centro_Oeste + valores_servicos_Centro_Oeste + valores_administracao_Centro_Oeste +
  valores_agropecuaria_Norte + valores_industria_Norte + valores_servicos_Norte + valores_administracao_Norte +
  valores_agropecuaria_Nordeste + valores_industria_Nordeste + valores_servicos_Nordeste + valores_administracao_Nordeste +
  valores_agropecuaria_Sul + valores_industria_Sul + valores_servicos_Sul + valores_administracao_Sul +
  valores_agropecuaria_Sudeste + valores_industria_Sudeste + valores_servicos_Sudeste + valores_administracao_Sudeste

total_brasil

print("")

total_industria_br = valores_industria_Centro_Oeste + valores_industria_Norte + valores_industria_Nordeste + valores_industria_Sul + valores_industria_Sudeste
total_industria_br

print("")

total_agro_br = valores_agropecuaria_Norte + valores_agropecuaria_Nordeste + valores_agropecuaria_Sul + valores_agropecuaria_Sudeste + valores_agropecuaria_Centro_Oeste
total_agro_br

print("")

total_servicos_br = valores_servicos_Norte + valores_servicos_Nordeste + valores_servicos_Sul + valores_servicos_Sudeste + valores_servicos_Centro_Oeste
total_servicos_br

print("")

total_adm_br = valores_administracao_Norte + valores_administracao_Nordeste + valores_administracao_Sul + valores_administracao_Sudeste + valores_administracao_Centro_Oeste
total_adm_br
# Out:
# [1] 6355130636
# [1] ""
# [1] 1473484799
# [1] ""
# [1] 432999113
# [1] ""
# [1] 3412863531
# [1] ""
# [1] 1035783192
# [1] 6355130636
# [1] ""
# [1] 1473484799
# [1] ""
# [1] 432999113
# [1] ""
# [1] 3412863531
# [1] ""
# [1] 1035783192
# [1] 6355130636
# [1] ""
# [1] 1473484799
# [1] ""
# [1] 432999113
# [1] ""
# [1] 3412863531
# [1] ""
# [1] 1035783192

# %%
# Fazer a contribuição de cada setor em termos de Brasil:



proporcao_total_agro = round((total_agro_br/ total_brasil)*100)
proporcao_total_agro

print("")

proporcao_total_industria = round((total_industria_br/ total_brasil)*100)
proporcao_total_industria

print("")

proporcao_total_servicos = round((total_servicos_br/ total_brasil)*100)
proporcao_total_servicos

print("")

proporcao_total_adm = round((total_adm_br/ total_brasil)*100)
proporcao_total_adm
# Out:
# [1] 7
# [1] ""
# [1] 23
# [1] ""
# [1] 54
# [1] ""
# [1] 16
# [1] 7
# [1] ""
# [1] 23
# [1] ""
# [1] 54
# [1] ""
# [1] 16
# [1] 7
# [1] ""
# [1] 23
# [1] ""
# [1] 54
# [1] ""
# [1] 16

# %%
setores = c("Agropecuária", "Indústria", "Serviços", "Administração")
valores = c(proporcao_total_agro, proporcao_total_industria, proporcao_total_servicos, proporcao_total_adm)

barplot(valores, names.arg = setores, xlab = "Setores da economia", ylab = "Proporção do PIB", main="Contribuição dos setores para o PIB", col="blue")
# Out:
# Plot with title “Contribuição dos setores para o PIB”
# Plot with title “Contribuição dos setores para o PIB”
# Plot with title “Contribuição dos setores para o PIB”
